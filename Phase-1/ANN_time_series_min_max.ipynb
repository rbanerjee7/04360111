# %%
# import helper
import pandas as pd
from utils import *

import time
import numpy as np
import math
import matplotlib.pyplot as plt

import torch
from torch.utils.data import DataLoader
from torch import nn

from IPython.display import Image

import torch
from torch import nn
from torch.utils.data import Dataset
import pennylane as qml
import torch.optim as optim
import torch.utils.data as data
import random
import tensorflow as tf

# %%
plt.rcParams["font.weight"] = "bold"
plt.rcParams["axes.labelweight"] = "bold"
plt.rcParams.update({'font.size':20})
legend_prop = {'weight':'bold'}
from pylab import rcParams
rcParams['axes.linewidth'] = 2

# %% [markdown]
# ## Data

# %% [markdown]
# First, we read in the data, dropping the index and the date.

# %%
df = pd.read_csv('dataset_FTSE_prediction_v1.csv')
df = df.drop([ 'Unnamed: 0'], axis=1)
df=df.drop(columns=['ARIMA'])
df=df[800:]

# %% [markdown]
# We identify the dependent and independent variables:

# %%
target = "Close"

# %%
features = list(df.columns.difference(["Close"]))
features
# Out:
# ['Adj Close',
#  'BBB_20_2.0',
#  'BBL_20_2.0',
#  'BBM_20_2.0',
#  'BBP_20_2.0',
#  'BBU_20_2.0',
#  'CUMLOGRET_1',
#  'Close_copy',
#  'Crude Futures',
#  'EMA_10',
#  'EMA_20',
#  'EMA_50',
#  'FT3',
#  'FT6',
#  'FT9',
#  'GBP USD ',
#  'Gold in USD',
#  'MACD_12_26_9',
#  'MACDh_12_26_9',
#  'MACDs_12_26_9',
#  'SMA_10',
#  'SMA_20',
#  'SMA_50',
#  'Volume']

# %% [markdown]
# ## Data processing for time series model

# %% [markdown]
# To process the data, we first define few terms

# %%
torch.manual_seed(42)
random.seed(42)

# %% [markdown]
# Next, in order to ensure that some values due to their mangnitude do not inherently dominate the features, we standardize their values.

# %%
close_min=min(df['Close'].values)
close_max=max(df['Close'].values)

# %%
a=0
b=1
normalized_df_2=(b-a)*((df-df.min())/(df.max()-df.min()))+a

# %%
target_mean = df[target].mean()
target_stdev = df[target].std()

for c in df.columns:
    mean = df[c].mean()
    stdev = df[c].std()

    df[c] = (df[c] - mean) / stdev

# %%
df['Close']=normalized_df_2['Close']

# %%
df
# Out:
#       Adj Close  BBB_20_2.0  BBL_20_2.0  BBM_20_2.0  BBP_20_2.0  BBU_20_2.0  \
# 800   -0.664382   -0.518756   -0.212867   -0.376660   -2.096023   -0.541526
# 801   -0.646763   -0.405198   -0.255201   -0.392525   -1.648446   -0.526270
# 802   -0.651849   -0.315221   -0.292326   -0.409164   -1.448674   -0.518568
# 803   -0.695260   -0.219031   -0.333231   -0.428391   -1.458203   -0.511942
# 804   -0.813687   -0.091393   -0.390878   -0.457822   -1.732959   -0.507468
# ...         ...         ...         ...         ...         ...         ...
# 3134   0.764009   -0.149978    0.687472    0.738442    0.156114    0.753486
# 3135   0.792344   -0.320354    0.718714    0.721971    0.421769    0.683547
# 3136   0.858642   -0.360917    0.725812    0.717688    0.821349    0.666530
# 3137   0.892608   -0.370429    0.727517    0.716729    1.019851    0.662588
# 3138   0.892608   -0.325773    0.724413    0.726719    0.921113    0.686933
#
#       CUMLOGRET_1     Close  Crude Futures    EMA_10  ...  GBP USD   \
# 800     -0.618721  0.544895       1.732245 -0.477768  ...  2.765372
# 801     -0.600796  0.548106       1.732245 -0.510207  ...  2.765372
# 802     -0.605967  0.547179       1.742954 -0.537690  ...  2.671345
# 803     -0.650199  0.539266       1.607479 -0.568214  ...  2.671345
# 804     -0.771680  0.517680       1.580170 -0.615116  ...  2.671345
# ...           ...       ...            ...       ...  ...       ...
# 3134     0.755674  0.805258       1.389541  0.775099  ... -0.713624
# 3135     0.781440  0.810422       1.353128  0.781322  ... -0.807650
# 3136     0.841517  0.822507       1.392218  0.798688  ... -0.807650
# 3137     0.872183  0.828698       1.391683  0.819186  ... -0.807650
# 3138     0.872183  0.828698       1.391683  0.835957  ... -0.807650
#
#       Gold in USD  MACD_12_26_9  MACDh_12_26_9  MACDs_12_26_9    SMA_10  \
# 800     -0.923083     -0.285174      -0.957418       0.029832 -0.442130
# 801     -0.947383     -0.387140      -1.015113      -0.059456 -0.471115
# 802     -0.935746     -0.466173      -1.005142      -0.147868 -0.500101
# 803     -0.959704     -0.550693      -1.010594      -0.236759 -0.531275
# 804     -0.945671     -0.686218      -1.139791      -0.336992 -0.572362
# ...           ...           ...            ...            ...       ...
# 3134     1.462017     -0.279086       0.658465      -0.531071  0.759355
# 3135     1.459964     -0.237484       0.628980      -0.476021  0.779237
# 3136     1.463044     -0.160380       0.692283      -0.415414  0.804912
# 3137     1.479814     -0.076886       0.758568      -0.348987  0.834026
# 3138     1.479814     -0.010920       0.768694      -0.281671  0.839893
#
#         SMA_20    SMA_50    Volume  Close_copy
# 800  -0.376660 -0.460099  0.479939   -0.664382
# 801  -0.392525 -0.463963 -0.746811   -0.646763
# 802  -0.409164 -0.467120 -0.835320   -0.651849
# 803  -0.428391 -0.473782  0.314693   -0.695260
# 804  -0.457822 -0.483073 -0.020605   -0.813687
# ...        ...       ...       ...         ...
# 3134  0.738442  0.919877 -1.255627    0.764009
# 3135  0.721971  0.918719 -1.228554    0.792344
# 3136  0.717688  0.916662 -0.521709    0.858642
# 3137  0.716729  0.915488 -0.821082    0.892608
# 3138  0.726719  0.914608 -0.821082    0.892608
#
# [2339 rows x 25 columns]

# %% [markdown]
# The last step in the data processing is to prepare the data in a sequence of past observations. Preparation of the time series data means that it uses a certain number of past observations to predict the future. In this case, the sequence length decides how many days the LSTM considers in advance and window decides how many days we want to predict for. If the sequence length is $n$ and window is $w$, then the LSTM considers the last $n$ observations to predict the next $w$ day price.

# %%
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_absolute_percentage_error
def cal_metrics(y_true,y_pred):
    mae=0
    rmse=0
    for i in range(len(y_true)):
        y1=y_true[i].flatten().numpy()* target_stdev + target_mean
        y2=y_pred[i].flatten()* target_stdev + target_mean
        mae=mean_absolute_error(y1, y2)+mae
        rmse=mean_squared_error(y1, y2, squared=False)+rmse  
    return mae/len(y_true) , rmse/len(y_true)

# %%
# Data for regression model
sequence_length_reg = window_reg =20 # Number of time steps that will be inputted into LSTM network

def create_dataset_reg(dataset,target,features, lookback, window):
    X_store, y_store = [], []
    for i in range(0,len(dataset)-lookback-window,5):
        X = (dataset[features].values)[i:i+lookback]
        y = (dataset[target].values)[i+lookback:i+lookback+window]
        X_store.append(X)
        y_store.append(y)
    return X_store,y_store

X_reg,y_reg = create_dataset_reg(
    df,
    target=target,
    features=features,
    lookback=sequence_length_reg, window=window_reg)

print(np.array(X_reg).shape, np.array(y_reg).shape)
# Out:
# (460, 20, 24) (460, 20)

# %%
indices = tf.range(start=0, limit=tf.shape(X_reg)[0])
shuffled_indices = tf.random.shuffle(indices)

# %%
X_reg = tf.gather(X_reg, shuffled_indices)
y_reg = tf.gather(y_reg, shuffled_indices)

# %%
# Train test split
m=np.array(X_reg).shape[0] # get first dimension
size=int(m*0.9)
X_train_reg=X_reg[:size]
y_train_reg=y_reg[:size]
X_test_reg=X_reg[size:]
y_test_reg=y_reg[size:]
print('Shape of train is',np.array(X_train_reg).shape,'and',np.array(y_train_reg).shape)
print('Shape os test is',np.array(X_test_reg).shape,'and',np.array(y_test_reg).shape)
# Out:
# Shape of train is (414, 20, 24) and (414, 20)
# Shape os test is (46, 20, 24) and (46, 20)

# %%
X_train_reg_=np.array([inner for outer in X_train_reg for inner in outer])
print(X_train_reg_.shape)
y_train_reg_=np.array([inner for outer in y_train_reg for inner in outer])
print(y_train_reg_.shape)
# Out:
# (8280, 24)
# (8280,)

# %%
X_test_reg_=np.array([inner for outer in X_test_reg for inner in outer])
print(X_test_reg_.shape)
y_test_reg_=np.array([inner for outer in y_test_reg for inner in outer])
print(y_test_reg_.shape)
# Out:
# (920, 24)
# (920,)

# %%
# Prepare test data
X_check_reg=(df[features].values)[len(df)-window_reg-sequence_length_reg:len(df)- window_reg]
y_check_reg=(df[target].values)[len(df)-window_reg:len(df)]

# %%
X_check_reg
# Out:
# array([[ 1.05844214, -0.19716968,  0.75959957,  0.80516313,  1.21592729,
#          0.81014498,  1.0208129 ,  1.05844214,  0.79302159,  0.8132752 ,
#          0.85160002,  1.05832725, -0.80714765, -0.40596154,  0.00628931,
#         -0.33751597,  1.66531029, -0.46132203,  1.0267621 , -0.85619257,
#          0.69737467,  0.80516313,  1.07490531,  0.33719206],
#        [ 1.16360979, -0.07160229,  0.73748563,  0.81858003,  1.46921145,
#          0.86331144,  1.11414635,  1.16360979,  0.80266014,  0.88129793,
#          0.88581386,  1.06690863, -0.81716517, -0.42146188, -0.01617262,
#         -0.43154287,  1.63382382, -0.19384604,  1.47645234, -0.7267417 ,
#          0.7646153 ,  0.81858003,  1.07164371, -0.57175877],
#        [ 1.19557785,  0.06292609,  0.71762843,  0.83736927,  1.37200998,
#          0.92509087,  1.14237711,  1.19557785,  0.87923305,  0.94287189,
#          0.91992414,  1.07651383, -0.82718633, -0.43698916, -0.03872802,
#         -0.43154287,  1.62013404,  0.03791227,  1.74878423, -0.57338238,
#          0.83943337,  0.83736927,  1.06813508, -1.04481641],
#        [ 1.22264172,  0.18997287,  0.70161387,  0.85831863,  1.27410117,
#          0.98698494,  1.16622638,  1.22264172,  0.96865736,  0.99826156,
#          0.95345673,  1.08689402, -0.83721086, -0.45254261, -0.06137438,
#         -0.43154287,  1.60644427,  0.23592914,  1.88406633, -0.40814644,
#          0.91388361,  0.85831863,  1.06430994, -0.99093137],
#        0.80525758, 0.81042246, 0.82250695, 0.82869819, 0.82869819])

# %% [markdown]
# ## ANN

# %%
from tensorflow.keras import regularizers, initializers
from keras.layers import Input, Dense, Reshape, Embedding, concatenate, Dropout, Flatten
from keras.layers.merge import Dot
from keras.preprocessing import sequence
from keras import Model

# %%
input_ = Input((len(features),)) # feature

den1=Dense(256, use_bias=True,activation='relu')(input_)

den2=Dense(128, use_bias=True,activation='relu')(den1)

den3=Dense(64, use_bias=True,activation='relu')(den2)

den4=Dense(32, use_bias=True,activation='relu')(den3)

den5=Dense(1, use_bias=True,activation='linear')(den4)

model = Model(inputs=[input_], outputs=den5)

# %%
import tensorflow as tf

# %%
loss_fn = tf.keras.losses.MeanSquaredError()
opt = tf.keras.optimizers.Adam(learning_rate=0.001)
model.compile(opt, loss=loss_fn)

# %%
model_history = model.fit(X_train_reg_, y_train_reg_,
                    validation_data=(X_test_reg_, y_test_reg_),
                   batch_size=32, 
                   epochs=300, shuffle=True
                   )
# Out:
# Epoch 1/300
# 259/259 [==============================] - 2s 4ms/step - loss: 0.0173 - val_loss: 0.0032
# Epoch 2/300
# 259/259 [==============================] - 1s 3ms/step - loss: 0.0024 - val_loss: 0.0018
# Epoch 3/300
# 259/259 [==============================] - 1s 3ms/step - loss: 0.0017 - val_loss: 0.0015
# Epoch 4/300
# 259/259 [==============================] - 1s 3ms/step - loss: 0.0015 - val_loss: 0.0010
# Epoch 5/300
# 259/259 [==============================] - 1s 4ms/step - loss: 0.0011 - val_loss: 9.0302e-04
# Epoch 6/300
# 259/259 [==============================] - 1s 3ms/step - loss: 9.9325e-04 - val_loss: 8.3031e-04
# Epoch 7/300
# 259/259 [==============================] - 1s 5ms/step - loss: 0.0010 - val_loss: 9.7932e-04
# Epoch 8/300
# 259/259 [==============================] - 1s 4ms/step - loss: 8.6465e-04 - val_loss: 9.3320e-04
# Epoch 9/300
# 259/259 [==============================] - 1s 3ms/step - loss: 9.2772e-04 - val_loss: 6.5608e-04
# Epoch 10/300
# 259/259 [==============================] - 1s 5ms/step - loss: 7.3149e-04 - val_loss: 5.6271e-04
# Epoch 11/300
# 259/259 [==============================] - 1s 4ms/step - loss: 7.4616e-04 - val_loss: 6.7282e-04
# Epoch 12/300
# 259/259 [==============================] - 1s 3ms/step - loss: 7.8843e-04 - val_loss: 6.0459e-04
# Epoch 13/300
# 259/259 [==============================] - 1s 3ms/step - loss: 8.3260e-04 - val_loss: 6.2160e-04
# Epoch 14/300
# 259/259 [==============================] - 1s 3ms/step - loss: 6.2084e-04 - val_loss: 7.3479e-04
# Epoch 15/300
# 259/259 [==============================] - 1s 4ms/step - loss: 5.5654e-04 - val_loss: 4.3610e-04
# Epoch 16/300
# 259/259 [==============================] - 1s 3ms/step - loss: 6.2903e-04 - val_loss: 5.5217e-04
# Epoch 17/300
# 259/259 [==============================] - 1s 3ms/step - loss: 8.5470e-04 - val_loss: 9.2377e-04
# Epoch 18/300
# 259/259 [==============================] - 1s 3ms/step - loss: 7.5138e-04 - val_loss: 7.0040e-04
# Epoch 19/300
# 259/259 [==============================] - 1s 3ms/step - loss: 6.0120e-04 - val_loss: 4.7261e-04
# Epoch 20/300
# 259/259 [==============================] - 1s 3ms/step - loss: 5.2117e-04 - val_loss: 4.1102e-04
# Epoch 21/300
# 259/259 [==============================] - 1s 3ms/step - loss: 4
300
# 259/259 [==============================] - 1s 3ms/step - loss: 1.5288e-04 - val_loss: 1.6899e-04
# Epoch 95/300
# 259/259 [==============================] - 1s 2ms/step - loss: 1.7753e-04 - val_loss: 1.5637e-04
# Epoch 96/300
# 259/259 [==============================] - 1s 2ms/step - loss: 1.3322e-04 - val_loss: 9.0977e-05
# Epoch 97/300
# 259/259 [==============================] - 1s 3ms/step - loss: 1.3883e-04 - val_loss: 1.3914e-04
# Epoch 98/300
# 259/259 [==============================] - 1s 3ms/step - loss: 1.4400e-04 - val_loss: 1.1491e-04
# Epoch 99/300
# 259/259 [==============================] - 1s 3ms/step - loss: 1.4083e-04 - val_loss: 2.5800e-04
# Epoch 100/300
# 259/259 [==============================] - 1s 3ms/step - loss: 1.3908e-04 - val_loss: 1.4602e-04
# Epoch 101/300
# 259/259 [==============================] - 1s 3ms/step - loss: 1.6481e-04 - val_loss: 1.2590e-04
# Epoch 102/300
# 259/259 [==============================] - 1s 3ms/step - loss: 1.1233e-04 - val_loss: 1.1848e-04
# Epoch 103/300
# 259/259 [==============================] - 1s 2ms/step - loss: 1.2626e-04 - val_loss: 1.0406e-04
# Epoch 104/300
# 259/259 [==============================] - 1s 2ms/step - loss: 1.0487e-04 - val_loss: 9.5393e-05
# Epoch 105/300
# 259/259 [==============================] - 1s 2ms/step - loss: 9.6042e-05 - val_loss: 8.8509e-05
# Epoch 106/300
# 259/259 [==============================] - 1s 3ms/step - loss: 1.1079e-04 - val_loss: 1.1573e-04
# Epoch 107/300
# 259/259 [==============================] - 1s 3ms/step - loss: 1.4016e-04 - val_loss: 2.2958e-04
# Epoch 108/300
# 259/259 [==============================] - 1s 3ms/step - loss: 1.5102e-04 - val_loss: 1.1576e-04
# Epoch 109/300
# 259/259 [==============================] - 1s 3ms/step - loss: 1.2158e-04 - val_loss: 1.2278e-04
# Epoch 110/300
# 259/259 [==============================] - 1s 3ms/step - loss: 2.1082e-04 - val_loss: 1.2347e-04
# Epoch 111/300
# 259/259 [==============================] - 1s 3ms/step - loss: 1.0073e-04 - val_loss: 9.4327e-05
# Epoch 112/300
# 259/259 [==============================] - ETA: 0s - loss: 8.4655e-0 - 1s 2ms/step - loss: 8.4532e-05 - val_loss: 7.4302e-05
# Epoch 113/300
# 259/259 [==============================] - 1s 3ms/step - loss: 1.7939e-04 - val_loss: 1.7412e-04
# Epoch 114/300
# 259/259 [==============================] - 1s 3ms/step - loss: 1.0123e-04 - val_loss: 1.2544e-04
# Epoch 115/300
# 259/259 [==============================] - 1s 3ms/step - loss: 9.2307e-05 - val_loss: 9.7330e-05
# Epoch 116/300
# 259/259 [==============================] - 1s 3ms/step - loss: 9.4233e-05 - val_loss: 9.8717e-05
# Epoch 117/300
# 259/259 [==============================] - 1s 3ms/step - loss: 9.5175e-05 - val_loss: 1.0708e-04
# Epoch 118/300
# 259/259 [==============================] - 1s 3ms/step - loss: 2.2155e-04 - val_loss: 1.6736e-04
# Epoch 119/300
# 259/259 [==============================] - 1s 3ms/step - loss: 1.3942e-04 - val_loss: 9.0379e-05
# Epoch 120/300
# 259/259 [==============================] - 1s 3ms/step - loss: 7.0910e-05 - val_loss: 7.2983e-05
# Epoch 121/300
# 259/259 [==============================] - 1s 3ms/step - loss: 7.0671e-05 - val_loss: 6.6907e-05
# Epoch 122/300
# 259/259 [==============================] - 1s 3ms/step - loss: 1.8849e-04 - val_loss: 1.7939e-04
# Epoch 123/300
# 259/259 [==============================] - 1s 3ms/step - loss: 1.5504e-04 - val_loss: 1.3838e-04
# Epoch 124/300
# 259/259 [==============================] - 1s 3ms/step - loss: 8.3505e-05 - val_loss: 7.1848e-05
# Epoch 125/300
# 259/259 [==============================] - 1s 3ms/step - loss: 6.1760e-05 - val_loss: 9.6255e-05
# Epoch 126/300
# 259/259 [==============================] - 1s 3ms/step - loss: 8.0632e-05 - val_loss: 9.4710e-05
# Epoch 127/300
# 259/259 [==============================] - 1s 3ms/step - loss: 7.9455e-05 - val_loss: 7.7923e-05
# Epoch 128/300
# 259/259 [==============================] - 1s 3ms/step - loss: 1
plt.plot(model_history.history['loss'])
plt.plot(model_history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# %%
def mae_metric(actual, predicted):
    sum_error = 0.0
    for i in range(len(actual)):
        sum_error += abs(predicted[i] - actual[i])
    return sum_error/len(actual)

def rmse_metric(actual, predicted):
    sum_error = 0.0
    for i in range(len(actual)):
        sum_error += (predicted[i] - actual[i])**2
    return (sum_error/len(actual))**0.5

# %%
# Predict the model 
y_train_pred_ann = model.predict(X_train_reg_) 
mae_train_ann = mae_metric((((y_train_reg_-a)/(b-a))*(close_max - close_min)) + close_min, ((np.array(y_train_pred_ann)-a)/(b-a))*(close_max - close_min)+ close_min)
print('MAE train: ',mae_train_ann)
rmse_train_ann = rmse_metric((((y_train_reg_-a)/(b-a))*(close_max - close_min)) + close_min,((np.array(y_train_pred_ann)-a)/(b-a))*(close_max - close_min)+ close_min)
print('RMSE train: ',rmse_train_ann)
# Out:
# MAE train:  [12.581251]
# RMSE train:  [17.846992]

# %%
# Predict the model 
y_test_pred_ann = model.predict(X_test_reg_) 
mae_test_ann = mae_metric((((y_test_reg_-a)/(b-a))*(close_max - close_min)) + close_min, ((np.array(y_test_pred_ann)-a)/(b-a))*(close_max - close_min)+ close_min)
print('MAE test: ',mae_test_ann)
rmse_test_ann = rmse_metric((((y_test_reg_-a)/(b-a))*(close_max - close_min)) + close_min,((np.array(y_test_pred_ann)-a)/(b-a))*(close_max - close_min)+ close_min)
print('RMSE test: ',rmse_test_ann)
# Out:
# MAE test:  [12.755166]
# RMSE test:  [17.590368]

# %%
model.summary()
# Out:
# Model: "model_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_3 (InputLayer)        [(None, 24)]              0
#
#  dense_10 (Dense)            (None, 256)               6400
#
#  dense_11 (Dense)            (None, 128)               32896
#
#  dense_12 (Dense)            (None, 64)                8256
#
#  dense_13 (Dense)            (None, 32)                2080
#
#  dense_14 (Dense)            (None, 1)                 33
#
# =================================================================
# Total params: 49,665
# Trainable params: 49,665
# Non-trainable params: 0
# _________________________________________________________________

# %%
y_check_pred_nn = model.predict(X_check_reg)
y_check_pred_nn=y_check_pred_nn.flatten()
mae_test_ann = mae_metric((((y_check_reg-a)/(b-a))*(close_max - close_min)) + close_min, ((np.array(y_check_pred_nn)-a)/(b-a))*(close_max - close_min)+ close_min)
print('MAE test: ',mae_test_ann)
rmse_test_ann = rmse_metric((((y_check_reg-a)/(b-a))*(close_max - close_min)) + close_min,((np.array(y_check_pred_nn)-a)/(b-a))*(close_max - close_min)+ close_min)
print('RMSE test: ',rmse_test_ann)
# Out:
# MAE test:  17.736508789062327
# RMSE test:  24.650826405712305

# %% [markdown]
# ## Comparison

# %%
plt.figure(figsize=(12, 7))
# plt.plot(y_test_reg* target_stdev + target_mean, label = "Real",marker='o')
plt.plot((((y_check_reg-a)/(b-a))*(close_max - close_min)), label = "Real",marker='o')
plt.plot((((y_check_pred_nn-a)/(b-a))*(close_max - close_min)), label = "ANN",marker='^')
plt.ylabel('Stock Price')
plt.xlabel('Days')
plt.legend()
plt.show()

# %%
plt.figure(figsize=(12, 7))
# plt.plot(y_test_reg* target_stdev + target_mean, label = "Real",marker='o')
plt.plot((((y_check_reg-a)/(b-a))*(close_max - close_min))[:14], label = "Real",marker='o')
plt.plot((((y_check_pred_nn-a)/(b-a))*(close_max - close_min))[:14], label = "ANN",marker='^')
plt.ylabel('Stock Price')
plt.xlabel('Days')
plt.legend()
plt.show()
