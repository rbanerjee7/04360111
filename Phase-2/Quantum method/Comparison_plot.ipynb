# %%
import pandas as pd
import time
import numpy as np
import math
import matplotlib.pyplot as plt

# %%
plt.rcParams["font.weight"] = "bold"
plt.rcParams["axes.labelweight"] = "bold"
plt.rcParams.update({'font.size':24})
legend_prop = {'weight':'bold'}
from pylab import rcParams
rcParams['axes.linewidth'] = 2

# %% [markdown]
# # First we compare classical and Quantum LSTM and then classical and quantum NN

# %% [markdown]
# # LSTM

# %% [markdown]
# # Classical result

# %%
# Train loss at learning rate of 0.001
lstm_loss_train=[0.45355936250727596,
 0.11527287226369362,
 0.08185798755868245,
 0.06374522935570652,
 0.0556238949412608,
 0.050382812841589214,
 0.04542949608747513,
 0.04194873298397501,
 0.03962179030227752,
 0.03639845809550913]

# %%
# Test loss at learning rate of 0.001
lstm_loss_test=[0.03372592618688941,
 0.03008799348026514,
 0.045939779840409756,
 0.06955239363014698,
 0.034197764936834574,
 0.05283508263528347,
 0.03963572718203068,
 0.03592234058305621,
 0.03374815289862454,
 0.06457534618675709]

# %%
# Train loss at learning rate of 0.05
lstm_loss_train_05=[0.17994795077060924,
 0.077880842426351,
 0.07755762847666522,
 0.08131612881392468,
 0.05807097084848708,
 0.06615820869746554,
 0.08562992494695514,
 0.054662599661991794,
 0.05065945326883829,
 0.049503041310449136]

# %%
# Test loss at learning rate of 0.001
lstm_loss_test_05=[0.29021554440259933,
 0.028350553009659052,
 0.02312728436663747,
 0.07708297204226255,
 0.02527844230644405,
 0.025585020892322063,
 0.032022980973124504,
 0.044751228764653206,
 0.034863049164414406,
 0.04647557297721505]

# %% [markdown]
# # 4 Qubit Quantum result

# %%
# Test loss at learning rate of 0.005 (NO-DRC)
nodrc_test_005=[0.3378449082374573,
 0.12000308930873871,
 0.088185153901577,
 0.0427134670317173,
 0.035599157214164734,
 0.040372975170612335,
 0.035334949692090355,
 0.03736712411046028,
 0.036975026751557984,
 0.04873033861319224]

# %%
# Train loss at learning rate of 0.005 (NO-DRC)
nodrc_train_005=[0.8033495921620422,
 0.2625447659837929,
 0.18675212828781118,
 0.16225577442144806,
 0.15157028715210882,
 0.13973360213937916,
 0.13264023368670183,
 0.12631355433470823,
 0.12321449037302624,
 0.11684490606950765]

# %%
# Train loss at learning rate of 0.05 (NO-DRC)
nodrc_train_05=[0.36558961773037235,
 0.10261335274712606,
 0.09441064139404758,
 0.07469772589816288,
 0.06891964816234329,
 0.06208644068630582,
 0.06118151240728118,
 0.05591836383841424,
 0.057989163366569715,
 0.0548208903902295]

# %%
# Test loss at learning rate of 0.05 (NO-DRC)
nodrc_test_05=[0.058463492741187416,
 0.09311554829279582,
 0.2894421915213267,
 0.043502659847339,
 0.057596066345771156,
 0.07099656263987224,
 0.02816636860370636,
 0.027817525590459507,
 0.24404198924700418,
 0.06885642558336258]

# %%
# Train loss at learning rate of 0.05 (DRC)
drc_train_05=[0.3906242814634673,
 0.11649886304935948,
 0.08872808162546293,
 0.07959630744616417,
 0.06782132681374523,
 0.06289786187963645,
 0.05483262819788334,
 0.053875085040503604,
 0.05074162924111905,
 0.049148078648034825]

# %%
# Test loss at learning rate of 0.05 (DRC)
drc_test_05=[0.03299530657629172,
 0.43495484193166095,
 0.03734951838850975,
 0.037670670077204704,
 1.127755085627238,
 0.06774791826804479,
 0.03959991844991843,
 0.03403880509237448,
 0.049959320574998856,
 0.04709770902991295]

# %% [markdown]
# # 6qubit

# %%
# Test loss at learning rate of 0.05 (NO-DRC)
nodrc6_test_05=[0.06684860835472743,
 0.03279369976371527,
 0.02435303044815858,
 0.05188494548201561,
 0.02891042393942674,
 0.027353941773374874,
 0.03344278410077095,
 0.021603199342886608,
 0.0270366333425045,
 0.024611884107192356]

# %%
# Train loss at learning rate of 0.05 (NO-DRC)
nodrc6_train_05=[0.25058370104736905,
 0.09632511977741326,
 0.0718173435465856,
 0.06157595559488982,
 0.054859120451675895,
 0.051645751471038566,
 0.05068334604782814,
 0.04823115152645518,
 0.04586728435771709,
 0.045101567298512564]

# %%
# Test loss at learning rate of 0.005 (NO-DRC)
nodrc6_test_005=[0.5665245056152344,
 0.08098526174823444,
 0.06577227140466373,
 0.042344833413759865,
 0.04119142144918442,
 0.03495875373482704,
 0.030793358261386555,
 0.02897600084543228,
 0.031993236392736435,
 0.028089245160420735]

# %%
# Train loss at learning rate of 0.005 (NO-DRC)
nodrc6_train_005=[0.7832824940877882,
 0.26671115546063945,
 0.18466541501270098,
 0.16268462488766422,
 0.14779895554635336,
 0.1379439555193213,
 0.1296308148144321,
 0.12305955746507441,
 0.11868233864449641,
 0.11317873109576547]

# %%
# Train loss at learning rate of 0.05 (DRC)
drc6_train_05=[0.24773440302603625,
 0.09431738560934635,
 0.07574208277616311,
 0.060840309682217514,
 0.0538634444502267,
 0.050044848467223346,
 0.04658146869306537,
 0.04385501146316528,
 0.04145936231097122,
 0.04005113092716783]

# %%
# Test loss at learning rate of 0.05 (DRC)
drc6_test_05=[0.05340713200469812,
 0.07742273124555747,
 0.05680138245224953,
 0.04613967488209406,
 0.03693466012676557,
 0.03070725438495477,
 0.03419346362352371,
 0.07390561203161876,
 0.03494897981484731,
 0.039710668846964836]

# %%
# Train loss at learning rate of 0.005 (DRC)
drc6_train_005=[0.54142911109904,
 0.2058949422260577,
 0.15925032129003244,
 0.13901530534283005,
 0.127167285843329,
 0.1191968156490475,
 0.11300605338659477,
 0.10943164041435177,
 0.10441717048260299,
 0.10141636128537357]

# %%
# Test loss at learning rate of 0.005 (DRC)
drc6_test_005=[0.2045124222834905,
 0.05484130481878916,
 0.034202914064129196,
 0.03357775447269281,
 0.024758161045610905,
 0.04009700504442056,
 0.030129436403512955,
 0.03980351736148199,
 0.031844510386387505,
 0.0358333308249712]

# %% [markdown]
# # Plots

# %%
plt.figure(figsize=(10, 8))
plt.plot(lstm_loss_train, label ="Classical LSTM")
plt.plot(drc6_train_05, label ="Quantum LSTM: 6 Qubit DRC")
plt.plot(drc_train_05, label ="Quantum LSTM: 4 Qubit DRC")
# plt.title('Train')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend()
plt.show()

# %%
plt.figure(figsize=(10, 8))
plt.plot(lstm_loss_test, label ="Classical LSTM")
plt.plot(drc6_test_05, label ="Quantum LSTM: 6 Qubit DRC")
# plt.plot(drc_test_05, label ="DRC 4Qubit")
plt.ylim(0, 0.1) 
# plt.title('Test')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend()
plt.show()

# %%
plt.figure(figsize=(10, 8))
plt.plot(drc_train_05, label ="DRC")
plt.plot(nodrc_train_05, label ="No DRC")
plt.title('6 Qubit Quantum circuit')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend()
plt.show()

# %%
plt.figure(figsize=(10, 8))
plt.plot(drc6_train_05, label ="DRC")
plt.plot(nodrc6_train_05, label ="No DRC")
plt.title('4 Qubit Quantum circuit')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend()
plt.show()

# %%
plt.figure(figsize=(10, 8))
plt.plot(lstm_loss_train, label ="Classical LSTM: lr=0.001")
plt.plot(lstm_loss_train_05, label ="Classical LSTM: lr=0.05")
plt.title('Train loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend()
plt.show()

# %%
plt.figure(figsize=(10, 8))
plt.plot(lstm_loss_test, label ="Classical LSTM: lr=0.001")
plt.plot(lstm_loss_test_05, label ="Classical LSTM: lr=0.05")
plt.title('Test loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend()
plt.show()

# %% [markdown]
# # Neural Network

# %%
qnn_test=[0.02449016,
 0.0064217,
 0.00509536,
 0.0057044,
 0.01290248,
 0.00993529,
 0.00577412,
 0.00334069,
 0.00886539,
 0.01837415,
 0.00923507,
 0.01734177,
 0.00726066,
 0.0082363,
 0.00663217]

# %%
qnn_train=[0.023613082609789244,
 0.01854311117123644,
 0.012453520764812055,
 0.011403825514160703,
 0.013556711651261882,
 0.021247254999760927,
 0.009597506202448482,
 0.011372007761889036,
 0.008032843816189104,
 0.012890795674827217,
 0.012634871133502552,
 0.009603613692778139,
 0.0095107931024976,
 0.007118442013375939,
 0.0072810770337642374]

# %%
proposed_nn_train=[0.06708294153213501,
 0.019941307604312897,
 0.014155708253383636,
 0.012348377145826817,
 0.01051285769790411,
 0.010377504862844944,
 0.009591298177838326,
 0.009211504831910133,
 0.009527436457574368,
 0.008504248224198818,
 0.008782656863331795,
 0.008089661598205566,
 0.00783243216574192,
 0.007729311008006334,
 0.007659022696316242]

# %%
proposed_nn_test=[0.006516306195408106,
 0.01721298135817051,
 0.009740255773067474,
 0.0048342738300561905,
 0.0035276426933705807,
 0.0048768226988613605,
 0.004744355566799641,
 0.006800520233809948,
 0.0058693792670965195,
 0.006434311158955097,
 0.004349349066615105,
 0.01235631387680769,
 0.006167810410261154,
 0.00987826194614172,
 0.005404644645750523]

# %%
plt.figure(figsize=(10, 8))
plt.plot(qnn_test, label ="Quantum proposed-ann")
plt.plot(proposed_nn_test, label ="Classical proposed-ann")
# plt.title('Test')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.ylim(.002,.05)
plt.legend()
plt.show()

# %%
plt.figure(figsize=(10, 8))
plt.plot(qnn_train, label ="Quantum proposed-ann")
plt.plot(proposed_nn_train, label ="Classical proposed-ann")
# plt.title('Train')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend()
plt.show()

# %%
plt.figure(figsize=(10, 8))
plt.plot(qnn_test, label ="Test")
plt.plot(qnn_train, label ="Train")
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.ylim(.002,.05)
plt.legend()
plt.show()
